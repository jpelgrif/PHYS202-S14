# %% [markdown]
# # Galaxy Mergers Project

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
## Initialize positions and velocities
G = 4.302 * 10**-6 ## kpc/(solar masses) * (km/s)^2 - from wikipedia
M = S = 10**11 ##solar masses
Rmin = 25 ##kpc
nlist = [12,18,24,30,36]
rfrac = [.2,.3,.4,.5,.6]
r0 = np.zeros(120)
th0 = np.zeros(120)

i = 0
for ni,n in enumerate(nlist):
    for x in range(n):
        r0[i] = rfrac[ni] * Rmin
        th0[i] = np.linspace(0,2*pi,n)[x]
        i += 1
       
x0 = r0*np.cos(th0)
y0 = r0*np.sin(th0)

v = sqrt(G*M/r0) ## km/s
vtheta = th0 + np.pi/2
vx0 = v*np.cos(vtheta)
vy0 = v*np.sin(vtheta)

##Rx0 = 
##Ry0 =
##vRx0 =
##vRy0 =

plt.figure(figsize=(6,6))
##plt.scatter(x0,y0)
plt.quiver(x0,y0,vx0,vy0)
plt.grid()

plt.show()

# %%
def deriv_xy(current,t,Rx,Ry):
    gamma = 4.302 * 10**-6 ## kpc/(solar masses) * (km/s)^2 - from wikipedia
    M = S = 10**11 ##solar masses

    x = current[0]
    y = current[1]
    r = sqrt(x**2+y**2)
    vx = current[2]
    vy = current[3]
    
    R = sqrt(Rx**2+Ry**2)
    
    px = Rx-x
    py = Ry-y
    p = R-r
    
    dx = vx
    dvx = -gamma * ( (M/r**3)*x - (S/p**3)*px + (S/R**3)*Rx)
    dy = vy
    dvy = -gamma * ( (M/r**3)*y - (S/p**3)*py + (S/R**3)*Ry)

    return np.array([dx,dy,dvx,dvy])

def deriv_R(current,t):
    gamma = 4.302 * 10**-6 ## kpc/(solar masses) * (km/s)^2 - from wikipedia
    M = S = 10**11 ##solar masses

    Rx = current[0]
    Ry = current[1]
    R = sqrt(Rx**2+Ry**2)
    vRx = current[2]
    vRy = current[3]

    dRx = vRx
    dvRx = -gamma * ((M+S) / R**3)*Rx
    dRy = vRy
    dvRy = -gamma * ((M+S) / R**3)*Ry

    return np.array([dRx,dRy,dvRx,dvRy])

# %%
t = np.arange(10.1)

x = np.zeros((len(t),120))
y = np.zeros((len(t),120))
vx = np.zeros((len(t),120))
vy = np.zeros((len(t),120))

R_init = np.array(Rx0,Ry0,vRx0,vRy0)
R = odeint(deriv_R,R_init,t)
Rx = R[:,0]; Ry = R[:,1]
Rvx = R[:,2]; Rvy = xy[:,3]

for i,(x0i,y0i,vx0i,vy0i) in enumerate(zip(x0,y0,vx0,vy0)):
    xy_init = np.array(x0i,y0i,vx0i,vy0i)
    xy = odeint(deriv_xy,xy_init,t,args=(Rx[i],Ry[i]))
    x[i] = xy[:,0]; y[i] = xy[:,1]
    vx[i] = xy[:,2]; vy[i] = xy[:,3]

print x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fef8f9f01162> in <module>()
#       6 vy = np.zeros((len(t),120))
#       7
# ----> 8 R_init = np.array(Rx0,Ry0,vRx0,vRy0)
#       9 R = odeint(deriv_R,R_init,t)
#      10 Rx = R[:,0]; Ry = R[:,1]
#
# NameError: name 'Rx0' is not defined

# %%
p = 2*Rmin
Rtheta = np.arange(-3*pi/4,3*pi/4+.001,pi/16)
Rr = p/(1+np.cos(Rtheta))

xxx = Rr*np.cos(Rtheta)
yyy = Rr*np.sin(Rtheta)

omega = p*np.sin(Rtheta)/((np.cos(Rtheta)+1)**2)
omegax = omega*np.cos(Rtheta)
omegay = omega*np.sin(Rtheta)

v = omega*Rr
print v

plt.plot(0,0,'ro')
plt.quiver(xxx,yyy,v,0)
plt.grid()
plt.show()
# Out:
# [ -7.03553391e+04  -2.36797423e+04  -9.81819280e+03  -4.70189039e+03
#   -2.50000000e+03  -1.43652027e+03  -8.73749776e+02  -5.52226849e+02
#   -3.55339059e+02  -2.26089204e+02  -1.34352591e+02  -6.27571965e+01
#    8.32667268e-13   6.27571965e+01   1.34352591e+02   2.26089204e+02
#    3.55339059e+02   5.52226849e+02   8.73749776e+02   1.43652027e+03
#    2.50000000e+03   4.70189039e+03   9.81819280e+03   2.36797423e+04
#    7.03553391e+04]
