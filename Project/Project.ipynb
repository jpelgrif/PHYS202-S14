# %% [markdown]
# # Galaxy Mergers Project

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
## Initialize positions and velocities
G = 4.493370168 * 10**-24 ## kpc/(solar masses) * (kpc/year)^2
M = S = 10**11 ##solar masses
Rmin = 25 ##kpc
nlist = [12,18,24,30,36]
rfrac = [.2,.3,.4,.5,.6]
r0 = np.zeros(120)
th0 = np.zeros(120)

i = 0
for ni,n in enumerate(nlist):
    for x in range(n):
        r0[i] = rfrac[ni] * Rmin
        th0[i] = np.linspace(0,2*pi,n)[x]
        i += 1
       
x0 = r0*np.cos(th0)
y0 = r0*np.sin(th0)

v = sqrt(G*M/r0) ## km/s
vtheta = th0 + np.pi/2
vx0 = v*np.cos(vtheta)
vy0 = v*np.sin(vtheta)

Rx0 = -120.710678119
Ry0 = 120.710678119
vRx0 = 427.296794646
vRy0 = 427.296794646/2
##Rx0 = 
##Ry0 =
##vRx0 =
##vRy0 =

plt.figure(figsize=(6,6))
##plt.scatter(x0,y0)
plt.quiver(x0,y0,vx0,vy0)
plt.grid()

plt.show()

# %%
def deriv_xy(current,t,Rx,Ry):
    gamma = 4.302 * 10**-6 ## kpc/(solar masses) * (km/s)^2 - from wikipedia
    M = S = 10**11 ##solar masses

    x = current[0]
    y = current[1]
    r = sqrt(x**2+y**2)
    vx = current[2]
    vy = current[3]
    
    R = sqrt(Rx**2+Ry**2)
    
    px = Rx-x
    py = Ry-y
    p = R-r
    
    dx = vx
    dvx = -gamma * ( (M/r**3)*x - (S/p**3)*px + (S/R**3)*Rx)
    dy = vy
    dvy = -gamma * ( (M/r**3)*y - (S/p**3)*py + (S/R**3)*Ry)

    return np.array([dx,dy,dvx,dvy])

def deriv_R(current,t):
    gamma = 4.493370168 * 10**-24 ## 4.302 * 10**-6 ## kpc/(solar masses) * (km/s)^2 - from wikipedia
    M = S = 10**11 ##solar masses

    Rx = current[0]
    Ry = current[1]
    R = sqrt(Rx**2+Ry**2)
    vRx = current[2]
    vRy = current[3]

    dRx = vRx
    dvRx = -gamma * ((M+S) / R**3)*Rx
    dRy = vRy
    dvRy = -gamma * ((M+S) / R**3)*Ry

    return np.array([dRx,dRy,dvRx,dvRy])

# %%
t = np.arange(10.1)

x = np.zeros((len(t),120))
y = np.zeros((len(t),120))
vx = np.zeros((len(t),120))
vy = np.zeros((len(t),120))

R_init = np.array([Rx0,Ry0,vRx0,vRy0])
R = odeint(deriv_R,R_init,t)
Rx = R[:,0]; Ry = R[:,1]
Rvx = R[:,2]; Rvy = R[:,3]

for i,(x0i,y0i,vx0i,vy0i) in enumerate(zip(x0,y0,vx0,vy0)):
    xy_init = np.array([x0i,y0i,vx0i,vy0i])
    xy = odeint(deriv_xy,xy_init,t,args=(Rx[i],Ry[i]))
    x[i] = xy[:,0]; y[i] = xy[:,1]
    vx[i] = xy[:,2]; vy[i] = xy[:,3]

print x
# Out:
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-59cfcc6c861d> in <module>()
#      14     xy_init = np.array([x0i,y0i,vx0i,vy0i])
#      15     xy = odeint(deriv_xy,xy_init,t,args=(Rx[i],Ry[i]))
# ---> 16     x[i] = xy[:,0]; y[i] = xy[:,1]
#      17     vx[i] = xy[:,2]; vy[i] = xy[:,3]
#      18
#
# ValueError: could not broadcast input array from shape (11) into shape (120)

# %%
p = 2*Rmin
Rtheta = np.arange(-3*pi/4,3*pi/4+.001,pi/16)
Rtheta = Rtheta[::-1]
Rr = p/(1+np.cos(Rtheta))

xxx = Rr*np.cos(Rtheta)
yyy = Rr*np.sin(Rtheta)


v = sqrt(abs(2*M*G/Rtheta))
             
vvx = v/sqrt(2)
vvy = v/sqrt(2)

print Rr
print xxx[0]
print yyy[0]
print vvx[0]
print vvy[0]
##print sqrt(vvx**2+vvy**2)

plt.figure(figsize=(6,6))
plt.plot(0,0,'ro')
##plt.quiver(xxx,yyy,vvx,vvy)
plt.plot(xxx,yyy)
plt.xlim(-150,150)
plt.ylim(-150,150)
plt.grid()
plt.show()
# Out:
# [ 170.71067812  112.50371536   80.99572022   62.11877105   50.
#    41.83784194   36.1615673    32.14255386   29.28932188   27.30048026
#    25.98915325   25.24251391   25.           25.24251391   25.98915325
#    27.30048026   29.28932188   32.14255386   36.1615673    41.83784194
#    50.           62.11877105   80.99572022  112.50371536  170.71067812]
# -120.710678119
# 120.710678119
# 4.36697324129e-07
# 4.36697324129e-07

# %%
t = np.arange(20.1)

x = np.zeros((len(t),120))
y = np.zeros((len(t),120))
vx = np.zeros((len(t),120))
vy = np.zeros((len(t),120))

Rx0 = -120.710678119
Ry0 = 120.710678119
vRx0 = 427.296794646
vRy0 = 427.296794646/2

R_init = np.array([Rx0,Ry0,vRx0,vRy0])
R = odeint(deriv_R,R_init,t)
Rx = R[:,0]; Ry = R[:,1]
Rvx = R[:,2]; Rvy = R[:,3]

print Rx
print Ry
plt.plot(Rx,Ry)
# Out:
# [ -120.71067812   306.58611653   733.88291117  1161.17970582  1588.47650047
#   2015.77329511  2443.07008976  2870.3668844   3297.66367905  3724.9604737
#   4152.25726834  4579.55406299  5006.85085763  5434.14765228  5861.44444693
#   6288.74124157  6716.03803622  7143.33483086  7570.63162551  7997.92842015
#   8425.2252148 ]
# [  120.71067812   334.35907544   548.00747277   761.65587009   975.30426741
#   1188.95266473  1402.60106206  1616.24945938  1829.8978567   2043.54625403
#   2257.19465135  2470.84304867  2684.491446    2898.13984332  3111.78824064
#   3325.43663796  3539.08503529  3752.73343261  3966.38182993  4180.03022726
#   4393.67862458]

# %%
for i,(x0i,y0i,vx0i,vy0i) in enumerate(zip(x0,y0,vx0,vy0)):
    xy_init = np.array([x0i,y0i,vx0i,vy0i])
    xy = odeint(deriv_xy,xy_init,t,args=(Rx[i],Ry[i]))
    x[i] = xy[:,0]; y[i] = xy[:,1]
    vx[i] = xy[:,2]; vy[i] = xy[:,3]

print x
