# %% [markdown]
# # ODE Exercises

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Question 1

# %% [markdown]
# For this question refer to the solutions for the simple pendulum we got using scipy's odeint from the beginning of the ODE Tour.
#
# (a) See what happens to the period of the pendulum as you change the initial angle of release. Plot θ vs t for 5 different initial angles, θ0 , spanning 0 to π. (i.e. 0, π/4 , π/2 , 3π/4 , and π ). Put them all on the same plot. What happens to the period of the pendulum as the initial angle increases from π/4 to 3π/4? What happens to the trajectory when the initial angle is 0 and π ?

# %%
from scipy.integrate import odeint

def deriv(theta_current,t):
    g = 9.8
    ell = 0.5
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/ell)*np.sin(theta)
    return np.array([dtheta,domega])

t = np.arange(0.,10.01,.01)
omega0 = 0.

th0 = 0
theta_init = np.array([th0, omega0])
theta = odeint(deriv,theta_init,t)
plt.plot(t,theta[:,0],label=r'$\theta_0= 0$')

th0 = pi/4
theta_init = np.array([th0, omega0])
theta = odeint(deriv,theta_init,t)
plt.plot(t,theta[:,0],label=r'$\theta_0 = \pi/4$')

th0 = pi/2
theta_init = np.array([th0, omega0])
theta = odeint(deriv,theta_init,t)
plt.plot(t,theta[:,0],label=r'$\theta_0 = \pi/2$')

th0 = 3*pi/4
theta_init = np.array([th0, omega0])
theta = odeint(deriv,theta_init,t)
plt.plot(t,theta[:,0],label=r'$\theta_0 = 3\pi/4$')

th0 = pi
theta_init = np.array([th0, omega0])
theta = odeint(deriv,theta_init,t)
plt.plot(t,theta[:,0],label=r'$\theta_0 = \pi$')

plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)
plt.grid()
plt.legend(loc="upper left", bbox_to_anchor=(1,1), fontsize=16)
plt.show()

# %% [markdown]
# (b) Make plots of θ vs. t, ω vs. t, and ω vs. θ (the so-called "phase plot") for θ0 = 0.95π. Look carefully at their behavior. What is going on in these figures?

# %%
t = np.arange(0.,10.01,.01)
omega0 = 0.

th0 = 0.95*pi
theta_init = np.array([th0, omega0])
theta = odeint(deriv,theta_init,t)

plt.figure(1)
plt.plot(t,theta[:,0])
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)
plt.ylim(-3.2,3.2)
plt.grid()

plt.figure(2)
plt.plot(t,theta[:,1],'g')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\omega (rad/s)$',fontsize=20)
plt.grid()

plt.figure(3)
plt.plot(theta[:,0],theta[:,1],'r')
plt.xlabel(r'$\theta (rad)$',fontsize=20)
plt.ylabel(r'$\omega (rad/s)$',fontsize=20)
plt.xlim(-3.2, 3.2)
plt.grid()

plt.show()

# %% [markdown]
# (c) For the θ0 = 0.95π case, check that energy is conserved by plotting E/m vs. t (where E/m=gℓcos(θ)+12ℓ^2ω^2 ).
#
# Is the energy a constant? If not, then the computational errors are producing a non-physical loss (or gain) of energy. Review the documentation for odeint and change the error tolerance value to a tighter number.

# %%
t = np.arange(0.,10.01,.01)
omega0 = 0.
ell = 0.5
g = 9.8

th0 = 0.95*pi
theta_init = np.array([th0, omega0])
theta = odeint(deriv,theta_init,t,rtol=1,atol=1.49012e-8)

Eoverm = g*ell*np.cos(theta[:,0]) + 0.5 * ell**2 * theta[:,1]**2

plt.plot(t,Eoverm)

plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$E/m$',fontsize=20)
plt.grid()
plt.show()

# %% [markdown]
# (d) Now look at what happens if we start the pendulum straight up, θ=π. Go for at least 50 s. Be sure to describe what happens numerically according to the θ vs. t, ω vs. t and E/m vs. t plots. What do you think should happen? What happens if you change the error tolerance on odeint? How does this compare to a nearly vertical pendulum: θ0=π−0.000001 ?

# %%
t = np.arange(0.,50.1,.1)
omega0 = 0.

th0 = pi
theta_init = np.array([th0, omega0])
theta = odeint(deriv,theta_init,t,rtol=1.49012e-8,atol=1.49012e-8)

plt.figure(1)
plt.plot(t,theta[:,0])
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)
plt.grid()

plt.figure(2)
plt.plot(t,theta[:,1],'g')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\omega (rad/s)$',fontsize=20)
plt.grid()

plt.figure(3)
plt.plot(theta[:,0],theta[:,1],'r')
plt.xlabel(r'$\theta (rad)$',fontsize=20)
plt.ylabel(r'$\omega (rad/s)$',fontsize=20)
plt.grid()

plt.show()

# %% [markdown]
# The graphs look very strange and not what I expect it to look like. Changing the error tolerance changes the graph, but I could not get it to look like how I think it should, mainly with theta remaining constant. I had the same problems with getting it to look as expected with the nearly vertical pendulum ($\theta_0=\pi-0.000001$).

# %%
t = np.arange(0.,50.1,.1)
omega0 = 0.

th0 = pi-0.000001
theta_init = np.array([th0, omega0])
theta = odeint(deriv,theta_init,t,rtol=1.49012e-8,atol=1.49012e-8)

plt.figure(1)
plt.plot(t,theta[:,0])
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)
##plt.ylim(-3.2,3.2)
plt.grid()

plt.figure(2)
plt.plot(t,theta[:,1],'g')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\omega (rad/s)$',fontsize=20)
plt.grid()

plt.figure(3)
plt.plot(theta[:,0],theta[:,1],'r')
plt.xlabel(r'$\theta (rad)$',fontsize=20)
plt.ylabel(r'$\omega (rad/s)$',fontsize=20)
##plt.xlim(-3.2, 3.2)
plt.grid()

plt.show()

# %% [markdown]
# ### Question 2

# %% [markdown]
# (a) Use Euler's method (not odeint) to solve the following first-order differential equation with given initial condition y(0) = 0.
#
# dy/dx=x+2y
#
# Find the value of y when x = 1, y(1), using two different step sizes: 0.25 then 0.02.

# %%
def EulerMethod(dx, xmax=10):
    nsteps = int(xmax/dx)+1
    x = np.zeros(nsteps)
    y = np.zeros(nsteps)
    
    for i in range(len(x)-1):
        x[i+1] = x[i] + dx
        y[i+1] = y[i] + dx * (x[i] + 2*y[i])
    
    return x,y

dx = .25
x,y = EulerMethod(dx)
print "Step size = %.2f: y(1) = %f" % (dx, y[x==1])

dx = 0.02
x,y = EulerMethod(dx)
print "Step size = %.2f: y(1) = %f" % (dx, y[50]) ## y[x==1] doesn't work for some reason on this one
# Out:
# Step size = 0.25: y(1) = 0.515625
# Step size = 0.02: y(1) = 1.026671

# %% [markdown]
# (b) Plot the results from part (a) for the two different step sizes with the exact solution
#
# y=0.25e^(2x) − 0.5x − 0.25
#
# on one plot. Include a legend. Which step size gives a more accurate result?

# %%
xExact = np.arange(0,5+.1,.1)
yExact = 0.25*exp(2*xExact) - 0.5*xExact - 0.25

x1,y1 = EulerMethod(0.25,xmax=5)
x2,y2 = EulerMethod(0.02,xmax=5)

plt.plot(xExact,yExact,label='exact solution')
plt.plot(x1,y1,label='step size = 0.25')
plt.plot(x2,y2,label='step size = 0.02')
plt.title('Euler Method',fontsize=20)
plt.xlabel('x',fontsize=16)
plt.ylabel('y',fontsize=16)
plt.legend(loc="upper left")
plt.show()

print "The smaller step size (0.02) gives a more accurate result"
# Out:
# The smaller step size (0.02) gives a more accurate result

# %% [markdown]
# (c) Now solve the same problem using Euler-Cromer and the Midpoint method for the same pair of step sizes and plot the results along with the exact solution. Then also plot the difference between the approximate numerical solutions and the exact solution. Which combination of method and step-size gives the best result?

# %%
def EulerCromer(dx, xmax=10):
    nsteps = int(xmax/dx)+1
    x = np.zeros(nsteps)
    y = np.zeros(nsteps)
    
    for i in range(len(x)-1):
        x[i+1] = x[i] + dx
        y[i+1] = y[i] + dx * (x[i+1] + 2*y[i])
    
    return x,y

xExact = np.arange(0,5+.02,.02)
yExact = 0.25*exp(2*xExact) - 0.5*xExact - 0.25

x1,y1 = EulerCromer(0.25,xmax=5)
x2,y2 = EulerCromer(0.02,xmax=5)

plt.figure(1)
plt.plot(xExact,yExact,label='exact solution')
plt.plot(x1,y1,label='step size = 0.25')
plt.plot(x2,y2,label='step size = 0.02')
plt.title('Euler-Cromer Method',fontsize=20)
plt.xlabel('x',fontsize=16)
plt.ylabel('y',fontsize=16)
plt.legend(loc="upper left")

def Midpoint(dx, xmax=10):
    nsteps = int(xmax/dx)+1
    x = np.zeros(nsteps)
    y = np.zeros(nsteps)
    
    for i in range(len(x)-1):
        x[i+1] = x[i] + dx
        y[i+1] = y[i] + dx * (0.5*(x[i+1]+x[i]) + 2*y[i])
    
    return x,y

x3,y3 = Midpoint(0.25,xmax=5)
x4,y4 = Midpoint(0.02,xmax=5)

plt.figure(2)
plt.plot(xExact,yExact,label='exact solution')
plt.plot(x3,y3,label='step size = 0.25')
plt.plot(x4,y4,label='step size = 0.02')
plt.title('Midpoint Method',fontsize=20)
plt.xlabel('x',fontsize=16)
plt.ylabel('y',fontsize=16)
plt.legend(loc="upper left")

x5,y5 = EulerMethod(0.02,xmax=5)

plt.figure(3)
plt.plot(xExact,abs(yExact-y5),label='Euler')
plt.plot(xExact,abs(yExact-y2),label='Euler-Cromer')
plt.plot(xExact,abs(yExact-y4),label='Midpoint')
plt.title('Difference between numerical and exact\n(step size = 0.02)',fontsize=16)
plt.xlabel(r'$x$',fontsize=20)
plt.ylabel(r'$\Delta y$',fontsize=20)
plt.legend(loc="upper left")

plt.show()

print "The most accurate combination of method and step-size is the Euler-Cromer method with a step size of 0.02"
# Out:
# The most accurate combination of method and step-size is the Euler-Cromer method with a step size of 0.02

# %% [markdown]
# ### Question 3

# %% [markdown]
# We can use numerical solvers and widgets to explore the dynamics of a projectile that is subject to a drag force proportional to the square of its velocity - "quadratic drag".
#
# The force on the projectile is given by
#
# ∑F⃗ =ma⃗
#
# =mg⃗ −cv2v^
#
# =mg⃗ −cvv⃗
#
# =mg⃗−cv2x+v2y‾‾‾‾‾‾‾√v⃗
#
# Where the second term is the drag force, in the direction opposite that of the velocity vector. Re-writing these in terms of the first-order differential equations for vx and vy gives
#
# mdvxdt=−cv2x+v2y‾‾‾‾‾‾‾√vx
#
# mdvydt=mg−cv2x+v2y‾‾‾‾‾‾‾√vy
#
# taking the positive y direction to be down. Notice that these are coupled equations. There are both vx and vy terms in each one. The drag coefficient c depends on the shape and density of the projectile. We can re-write this system of equations in terms of the terminal velocity - the point at which the gravitational force balances the drag force. This happens when mg=cv2. Let's denote the terminal velocity as vter=mg/c‾‾‾‾‾√ and re-write our equations in terms of vter.
#
# dvxdt=−gmvxv2terv2x+v2y‾‾‾‾‾‾‾√
#
# dvydt=−gm(1+vyv2terv2x+v2y‾‾‾‾‾‾‾√)
#
# (a) Create a derivative function to solve this system of equations and use odeint to solve it for a projectile fired at an angle of 50 degrees from the horizontal at an initial speed of 30 m/s. Track the projectile's motion over the time interval of 0 to 200 seconds and let (x0,y0) = (0,0). You'll have to calculate (vx0,vy0) from the information provided. Let vter=44 m/s. Plot the trajectory of the projectile (y vs. x) to see how far it can travel in the x direction before landing.

# %%
def deriv(xy_current,t,vter=44):
    g = 9.8 ## m/s^2
    ##vter = 44 m/s

    x = xy_current[0]
    y = xy_current[1]
    vx = xy_current[2]
    vy = xy_current[3]
    
    dx = vx
    dy = vy
    dvx = -g*(vx/(vter**2))*sqrt(vx**2 + vy**2)
    dvy = -g*(1+(vy/(vter**2))*sqrt(vx**2 + vy**2))
    return np.array([dx,dy,dvx,dvy])

t = np.arange(0.0,200.1,.1)

x0 =0.
y0 = 0.
vx0 = 30. * np.cos(50.*np.pi/180.)
vy0 = 30. * np.sin(50.*np.pi/180.)

xy_init = np.array([x0,y0,vx0,vy0])

xy = odeint(deriv,xy_init,t)

x = xy[:,0]; y = xy[:,1]
vx = xy[:,2]; vy = xy[:,3]

plt.plot(x,y)
plt.ylim(0,max(y)*1.05)
plt.xlabel('x (m)',fontsize=18)
plt.ylabel('y (m)',fontsize=18)
plt.show()

# %% [markdown]
# (b) Now create an interact object that uses sliders for the initial speed, terminal velocity, launch angle, and time. Have it plot two curves - one representing the solution with quadratic drag and the other in the absence of drag:
#
# x(t)=x0+vx0t
#
# y(t)=y0+vy0t−(1/2)gt^2

# %%
from IPython.html.widgets import interact
def Projectile(y0 = 0.,v0 = 30.,theta=50.,vter=44):
    g = 9.8 ## m/s^2
    
    t = np.arange(0.,200.1,.1)
    
    x0 =0.
    vx0 = v0 * np.cos(theta*np.pi/180.)
    vy0 = v0 * np.sin(theta*np.pi/180.)
    
    xy_init = np.array([x0,y0,vx0,vy0])
    
    xy = odeint(deriv,xy_init,t,args=(vter,))
    
    x1 = xy[:,0]
    y1 = xy[:,1]

    x2 = x0 + vx0 * t
    y2 = y0 + vy0 * t - 0.5 * g * t**2
        
    plt.plot(x1,y1,label='with drag')
    plt.plot(x2,y2,label='without drag')
    plt.ylim(0,50)
    plt.xlim(0,200)
    plt.title('Projectile Motion',fontsize=18)
    plt.xlabel('x (m)',fontsize=18)
    plt.ylabel('y (m)',fontsize=18)
    plt.legend()
    plt.show()
    
v = interact(Projectile,y0=(0.,5.),v0=(0.,60.),theta=(0.,90.),vter=(30.,120.))

# %% [markdown]
# (c) Use your interact object to find 3 pairs of initial angle and speed needed for the following projectiles to reach a target 80 m away. How do the values change if there is no air resistance? Put your results in a table for easier reading.
# <table>
# <tbody><tr><th>
# Projectile
# </th><th>
# Terminal velocity (m/s)
# </th><th>
# Initial height (m)
# </th></tr>
# <tr><td>
# Golfball
# </td><td>
# 44
# </td><td>
# 0
# </td></tr>
# <tr><td>
# Baseball
# </td><td>
# 43
# </td><td>
# 1.5
# </td></tr>
# <tr><td>
# Pumpkin
# </td><td>
# 107
# </td><td>
# 1.5
# </td></tr>
# </tbody></table>

# %%
def ProjectileZoomed(y0 = 0.,v0 = 30.,theta=45.,vter=44):
    g = 9.8 ## m/s^2
    
    t = np.arange(0.,200.1,.1)
    
    x0 =0.
    vx0 = v0 * np.cos(theta*np.pi/180.)
    vy0 = v0 * np.sin(theta*np.pi/180.)
    
    xy_init = np.array([x0,y0,vx0,vy0])
    
    xy = odeint(deriv,xy_init,t,args=(vter,))
    
    x1 = xy[:,0]
    y1 = xy[:,1]
    
    x2 = x0 + vx0 * t
    y2 = y0 + vy0 * t - 0.5 * g * t**2
        
    plt.plot(x1,y1,label='with drag')
    plt.plot(x2,y2,label='without drag')
    plt.ylim(0,50)
    plt.xlim(60,100)
    plt.title('Projectile Motion',fontsize=18)
    plt.xlabel('x (m)',fontsize=18)
    plt.ylabel('y (m)',fontsize=18)
    plt.legend()
    plt.show()
    
v2 = interact(ProjectileZoomed,y0=(0.,5.),v0=(20,40.,.1),theta=(0.,90.),vter=(30.,120.,.5))

# %% [markdown]
# **With air resistance**, initial angle and velocity for projectile to reach 80 m:
#
# Projectile | Initial angle (degrees) | Initial velocity (m/s)
# ---------- | ----------------------- | ----------------------
# Golfball   | 45                      | 33.3
# Baseball   | 45                      | 33.3
# Pumpkin    | 45                      | 28.5
#
# **Without air resistance**, initial angle and velocity for projectile to reach 80 m:
#
# Projectile | Initial angle (degrees) | Initial velocity (m/s)
# ---------- | ----------------------- | ----------------------
# Golfball   | 45                      | 28.0
# Baseball   | 45                      | 27.7
# Pumpkin    | 45                      | 27.7
